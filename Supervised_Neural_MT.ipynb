# %% [markdown]
# <a href="https://colab.research.google.com/github/priyanshu2103/Sanskrit-Hindi-Machine-Translation/blob/main/Supervised_Neural_MT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **```Supervised Neural Machine Translation```**

# %% [markdown]
# This notebook runs Seq2Seq model to translate Sanskrit to English, which we translate to Hindi using Google Translate.

# %% [markdown]
# NOTE: This requires GPU to run. With only CPU, processing can be painfully slow, with GPU also, training takes around 1.5 hrs

# %%
# !rm -rf sample_data
from __future__ import unicode_literals, print_function, division
from io import open
import unicodedata
import string
import re
import random

import torch
import torch.nn as nn
from torch import optim
import torch.nn.functional as F

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# This is the repo which contains the parallel data we are going to use.

# %%
# %cd /content
# !git clone https://github.com/priyanshu2103/Sanskrit-Hindi-Machine-Translation.git
# Out:
# /content
# Cloning into 'Sanskrit-Hindi-Machine-Translation'...
# remote: Enumerating objects: 67, done.
# remote: Counting objects: 100% (67/67), done.
# remote: Compressing objects: 100% (51/51), done.
# remote: Total 67 (delta 17), reused 60 (delta 13), pack-reused 0
# Unpacking objects: 100% (67/67), done.

# %%
# %cd /content/Sanskrit-Hindi-Machine-Translation/parallel-corpus/sanskrit-english/

eng_lines = []
sanskrit_lines = []
with open('bhagvadgita_english.txt', 'r') as f:
  eng_lines.extend([x.replace('\n', '') for x in f.readlines()])

with open('bible_english.txt', 'r') as f:
  eng_lines.extend([x.replace('\n', '') for x in f.readlines()])

with open('manu_english.txt', 'r') as f:
  eng_lines.extend([x.replace('\n', '') for x in f.readlines()])

with open('ramayan_english.txt', 'r') as f:
  eng_lines.extend([x.replace('\n', '') for x in f.readlines()])

with open('rigveda_english.txt', 'r') as f:
  eng_lines.extend([x.replace('\n', '') for x in f.readlines()])



with open('bhagvadgita_sanskrit.txt', 'r') as f:
  sanskrit_lines.extend([x.replace('\n', '') for x in f.readlines()])

with open('bible_sanskrit.txt', 'r') as f:
  sanskrit_lines.extend([x.replace('\n', '') for x in f.readlines()])

with open('manu_sanskrit.txt', 'r') as f:
  sanskrit_lines.extend([x.replace('\n', '') for x in f.readlines()])

with open('ramayan_sanskrit.txt', 'r') as f:
  sanskrit_lines.extend([x.replace('\n', '') for x in f.readlines()])

with open('rigveda_sanskrit.txt', 'r') as f:
  sanskrit_lines.extend([x.replace('\n', '') for x in f.readlines()])

# print(eng_lines[:100])
# print(sanskrit_lines[:100])

print(len(eng_lines))
print(len(sanskrit_lines))
# Out:
# /content/Sanskrit-Hindi-Machine-Translation/parallel-corpus/sanskrit-english
# [' Dhrtarastra said O Sanjaya ! What did my men and the sons of Pandu do in the Kuruksetra, the field of righteousness, where the entire warring class has assembled ?orO Sanjaya ! What did the selfish intentions and the intentions born of wisdom do in the human body which is the field-of-duties, the repository of the senseorgans and in which all the murderous ones (passions and asceticism etc.) are confronting [each other].', ' Sanjaya said Seeing the army of the sons of Pandu, marshalled in the military array, the prince Duryodhana approached the teacher (Drona) and spoke at that time, these words:', " O teacher ! Behold this mighty army of the sons of Pandu, marshalled in a military array by Drupada's son, your intelligent pupil.", ' The heroes and mighty archers, comparable in war to Bhima and Arjuna, here are: Yuyudhana, the king of the Virata country, and Drupada, the mighty warrior;', ' Dhrstaketu, Cekitana and the valourous king of Kasi, and Kuntibhoja, the coneror of many,  and the S
# 34374
# 34374

# %%
# Randomly shuffling the data into training and dev set, the test data is already provided on github
import random
c = list(zip(sanskrit_lines, eng_lines))
random.shuffle(c)

sanskrit_lines, eng_lines = zip(*c)

train_text_sa = sanskrit_lines[:-1374]
train_text_en = eng_lines[:-1374]

dev_text_sa = sanskrit_lines[-1374:]
dev_text_en = eng_lines[-1374:]

# %%
print(len(train_text_en))
print(len(dev_text_en))
# Out:
# 33000
# 1374

# %%
# Start and End tokens
SOS_token = 0
EOS_token = 1


class Lang:
    def __init__(self, name):
        self.name = name
        self.word2index = {}
        self.word2count = {}
        self.index2word = {0: "SOS", 1: "EOS"}
        self.n_words = 2  # Count SOS and EOS

    def addSentence(self, sentence):
        for word in sentence.split(' '):
            self.addWord(word)

    def addWord(self, word):
        if word not in self.word2index:
            self.word2index[word] = self.n_words
            self.word2count[word] = 1
            self.index2word[self.n_words] = word
            self.n_words += 1
        else:
            self.word2count[word] += 1

# %%
# Reading the data and forming pairs
def readLangs(lang1, lang2, reverse=False):
    print("Reading lines...")

    # Forming pairs of sentences
    pairs = [[train_text_sa[i], train_text_en[i]] for i in range(len(train_text_sa))]

    # Reverse pairs, make Lang instances
    if reverse:
        pairs = [list(reversed(p)) for p in pairs]
        input_lang = Lang(lang2)
        output_lang = Lang(lang1)
    else:
        input_lang = Lang(lang1)
        output_lang = Lang(lang2)

    return input_lang, output_lang, pairs

# %% [markdown]
# Filtering the data by only keeping sentences of length less than 100 words

# %%
MAX_LENGTH = 100

def filterPair(p):
    return len(p[0].split(' ')) < MAX_LENGTH and len(p[1].split(' ')) < MAX_LENGTH

def filterPairs(pairs):
    return [pair for pair in pairs if filterPair(pair)]

# %%
def prepareData(lang1, lang2, reverse=False):
    input_lang, output_lang, pairs = readLangs(lang1, lang2, reverse)
    print("Read %s sentence pairs" % len(pairs))
    pairs = filterPairs(pairs)
    print("Trimmed to %s sentence pairs" % len(pairs))
    print("Counting words...")
    for pair in pairs:
        input_lang.addSentence(pair[0])
        output_lang.addSentence(pair[1])
    print("Counted words:")
    print(input_lang.name, input_lang.n_words)
    print(output_lang.name, output_lang.n_words)
    return input_lang, output_lang, pairs


input_lang, output_lang, pairs = prepareData('sanskrit', 'eng', False)
print(random.choice(pairs)) # a random pair of parallel sentences
# Out:
# Reading lines...
# Read 32974 sentence pairs
# Trimmed to 32910 sentence pairs
# Counting words...
# Counted words:
# sanskrit 124240
# eng 44874
# ['यच्च गङ्गावतरणं त्वया कृतमरिन्दम। अनेन च भवान् प्राप्तो धर्मस्यायतनं महत्।।', 'O Destroyer of enemies by bringing about the descent of Ganga, you have secured a great abode in dharma.']

# %% [markdown]
# Seq2Seq Model
# =================
#
# A seq2seq network is a model consisting of two RNNs called the encoder and decoder. The encoder reads an input sequence and outputs a single vector, and the decoder reads that vector to produce an output sequence.
#
# Unlike sequence prediction with a single RNN, where every input
# corresponds to an output, the seq2seq model frees us from sequence
# length and order, which makes it ideal for translation between two
# languages.

# %% [markdown]
# The Encoder
# -----------
#
# The encoder of a seq2seq network is a RNN that outputs some value for
# every word from the input sentence. For every input word the encoder
# outputs a vector and a hidden state, and uses the hidden state for the
# next input word.

# %%
class EncoderRNN(nn.Module):
    def __init__(self, input_size, hidden_size):
        super(EncoderRNN, self).__init__()
        self.hidden_size = hidden_size

        self.embedding = nn.Embedding(input_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size)

    def forward(self, input, hidden):
        embedded = self.embedding(input).view(1, 1, -1)
        output = embedded
        output, hidden = self.gru(output, hidden)
        return output, hidden

    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

# %% [markdown]
# The Decoder
# -----------
#
# The decoder is another RNN that takes the encoder output vector(s) and
# outputs a sequence of words to create the translation.

# %% [markdown]
# Attention Decoder
#
# If only the context vector is passed betweeen the encoder and decoder,
# that single vector carries the burden of encoding the entire sentence.
#
# Attention allows the decoder network to "focus" on a different part of
# the encoder's outputs for every step of the decoder's own outputs. First
# we calculate a set of *attention weights*. These will be multiplied by
# the encoder output vectors to create a weighted combination. The result
# (called ``attn_applied`` in the code) should contain information about
# that specific part of the input sequence, and thus help the decoder
# choose the right output words.
#
# Calculating the attention weights is done with another feed-forward
# layer ``attn``, using the decoder's input and hidden state as inputs.
# Because there are sentences of all sizes in the training data, to
# actually create and train this layer we have to choose a maximum
# sentence length (input length, for encoder outputs) that it can apply
# to. Sentences of the maximum length will use all the attention weights,
# while shorter sentences will only use the first few.

# %%
class AttnDecoderRNN(nn.Module):
    def __init__(self, hidden_size, output_size, dropout_p=0.1, max_length=MAX_LENGTH):
        super(AttnDecoderRNN, self).__init__()
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.dropout_p = dropout_p
        self.max_length = max_length

        self.embedding = nn.Embedding(self.output_size, self.hidden_size)
        self.attn = nn.Linear(self.hidden_size * 2, self.max_length)
        self.attn_combine = nn.Linear(self.hidden_size * 2, self.hidden_size)
        self.dropout = nn.Dropout(self.dropout_p)
        self.gru = nn.GRU(self.hidden_size, self.hidden_size)
        self.out = nn.Linear(self.hidden_size, self.output_size)

    def forward(self, input, hidden, encoder_outputs):
        embedded = self.embedding(input).view(1, 1, -1)
        embedded = self.dropout(embedded)

        attn_weights = F.softmax(
            self.attn(torch.cat((embedded[0], hidden[0]), 1)), dim=1)
        attn_applied = torch.bmm(attn_weights.unsqueeze(0),
                                 encoder_outputs.unsqueeze(0))

        output = torch.cat((embedded[0], attn_applied[0]), 1)
        output = self.attn_combine(output).unsqueeze(0)

        output = F.relu(output)
        output, hidden = self.gru(output, hidden)

        output = F.log_softmax(self.out(output[0]), dim=1)
        return output, hidden, attn_weights

    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

# %% [markdown]
# Training
# ========
#
# Preparing Training Data
# -----------------------
#
# To train, for each pair we will need an input tensor (indexes of the
# words in the input sentence) and target tensor (indexes of the words in
# the target sentence). While creating these vectors we will append the
# EOS token to both sequences.

# %%
import random
def indexesFromSentence(lang, sentence):
    res = []
    for word in sentence.split(' '):
      if word not in lang.word2index.keys():
        res.append(random.choice(list(lang.word2index.values())))    
      else:
        res.append(lang.word2index[word])
    return res

def tensorFromSentence(lang, sentence):
    indexes = indexesFromSentence(lang, sentence)
    indexes.append(EOS_token)
    return torch.tensor(indexes, dtype=torch.long, device=device).view(-1, 1)


def tensorsFromPair(pair):
    input_tensor = tensorFromSentence(input_lang, pair[0])
    target_tensor = tensorFromSentence(output_lang, pair[1])
    return (input_tensor, target_tensor)

# %% [markdown]
# Training the Model
# ------------------
#
# To train we run the input sentence through the encoder, and keep track
# of every output and the latest hidden state. Then the decoder is given
# the ``<SOS>`` token as its first input, and the last hidden state of the
# encoder as its first hidden state.

# %%
teacher_forcing_ratio = 0.5
def train(input_tensor, target_tensor, encoder, decoder, encoder_optimizer, decoder_optimizer, criterion, max_length=MAX_LENGTH):
    encoder_hidden = encoder.initHidden()

    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    input_length = input_tensor.size(0)
    target_length = target_tensor.size(0)

    encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device=device)

    loss = 0

    for ei in range(input_length):
        encoder_output, encoder_hidden = encoder(
            input_tensor[ei], encoder_hidden)
        encoder_outputs[ei] = encoder_output[0, 0]

    decoder_input = torch.tensor([[SOS_token]], device=device)

    decoder_hidden = encoder_hidden

    use_teacher_forcing = True if random.random() < teacher_forcing_ratio else False

    if use_teacher_forcing:
        for di in range(target_length):
            decoder_output, decoder_hidden, decoder_attention = decoder(
                decoder_input, decoder_hidden, encoder_outputs)
            loss += criterion(decoder_output, target_tensor[di])
            decoder_input = target_tensor[di]

    else:
        for di in range(target_length):
            decoder_output, decoder_hidden, decoder_attention = decoder(
                decoder_input, decoder_hidden, encoder_outputs)
            topv, topi = decoder_output.topk(1)
            decoder_input = topi.squeeze().detach()

            loss += criterion(decoder_output, target_tensor[di])
            if decoder_input.item() == EOS_token:
                break

    loss.backward()

    encoder_optimizer.step()
    decoder_optimizer.step()

    return loss.item() / target_length

# %%
# Print time elapsed and estimated time remaining given the current time and progress %.
import time
import math


def asMinutes(s):
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)

def timeSince(since, percent):
    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s
    return '%s (- %s)' % (asMinutes(s), asMinutes(rs))

# %%
# Each iteration of training
def trainIters(encoder, decoder, n_iters, print_every=1000, plot_every=100, learning_rate=0.01):
    start = time.time()
    plot_losses = []
    print_loss_total = 0  # Reset every print_every
    plot_loss_total = 0  # Reset every plot_every

    encoder_optimizer = optim.SGD(encoder.parameters(), lr=learning_rate)
    decoder_optimizer = optim.SGD(decoder.parameters(), lr=learning_rate)
    training_pairs = [tensorsFromPair(random.choice(pairs))
                      for i in range(n_iters)]
    criterion = nn.NLLLoss()

    for iter in range(1, n_iters + 1):
        training_pair = training_pairs[iter - 1]
        input_tensor = training_pair[0]
        target_tensor = training_pair[1]

        loss = train(input_tensor, target_tensor, encoder,
                     decoder, encoder_optimizer, decoder_optimizer, criterion)
        print_loss_total += loss
        plot_loss_total += loss

        if iter % print_every == 0:
            print_loss_avg = print_loss_total / print_every
            print_loss_total = 0
            print('%s (%d %d%%) %.4f' % (timeSince(start, iter / n_iters),
                                         iter, iter / n_iters * 100, print_loss_avg))

        if iter % plot_every == 0:
            plot_loss_avg = plot_loss_total / plot_every
            plot_losses.append(plot_loss_avg)
            plot_loss_total = 0

    showPlot(plot_losses)

# %% [markdown]
# Evaluation
# ==========
#
# Evaluation is mostly the same as training, but there are no targets so
# we simply feed the decoder's predictions back to itself for each step.
# Every time it predicts a word we add it to the output string, and if it
# predicts the EOS token we stop there.

# %%
def evaluate(encoder, decoder, sentence, max_length=MAX_LENGTH):
    with torch.no_grad():
        input_tensor = tensorFromSentence(input_lang, sentence)
        input_length = input_tensor.size()[0]
        encoder_hidden = encoder.initHidden()

        encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device=device)

        for ei in range(input_length):
            encoder_output, encoder_hidden = encoder(input_tensor[ei],
                                                     encoder_hidden)
            encoder_outputs[ei] += encoder_output[0, 0]

        decoder_input = torch.tensor([[SOS_token]], device=device)  # SOS

        decoder_hidden = encoder_hidden

        decoded_words = []
        decoder_attentions = torch.zeros(max_length, max_length)

        for di in range(max_length):
            decoder_output, decoder_hidden, decoder_attention = decoder(
                decoder_input, decoder_hidden, encoder_outputs)
            decoder_attentions[di] = decoder_attention.data
            topv, topi = decoder_output.data.topk(1)
            if topi.item() == EOS_token:
                decoded_words.append('<EOS>')
                break
            else:
                decoded_words.append(output_lang.index2word[topi.item()])

            decoder_input = topi.squeeze().detach()

        return decoded_words, decoder_attentions[:di + 1]

# %%
def evaluate_test(encoder, decoder):
  with open('/content/eng_translated.en', 'w') as f:
    for i in range(len(dev_text_sa)):
      pair = [dev_text_sa[i], dev_text_en[i]]
      print('>', pair[0])
      print('=', pair[1])
      output_words, attentions = evaluate(encoder, decoder, pair[0])
      output_sentence = ' '.join(output_words)
      print('<', output_sentence)
      print('')
      f.write(output_sentence + '\n')

# %%
# defining hidden layer size and the encoder and decoder networks
hidden_size = 256

encoder1 = EncoderRNN(input_lang.n_words, hidden_size).to(device)
attn_decoder1 = AttnDecoderRNN(hidden_size, output_lang.n_words, dropout_p=0.1).to(device)

# train
trainIters(encoder1, attn_decoder1, 75000, print_every=5000)

# %%
# saving the trained models
torch.save(encoder1.state_dict(), '/content/trained_encoder.pth')
torch.save(attn_decoder1.state_dict(), '/content/trained_decoder.pth')

# %%
import nltk
def bleu(encoder, decoder, n=1000):
  
  candidate = []
  reference = []
  for i in range(n):
      pair = temp[i]
      # print('>', pair[0])
      # print('=', pair[1])
      output_words, attentions = evaluate(encoder, decoder, pair[0])
      output_sentence = ' '.join(output_words)
      reference.append(pair[1].split())
      candidate.append(output_sentence.split())
      # print('<', output_sentence)
      # print('')
  print("bleu", nltk.translate.bleu_score.corpus_bleu(reference, candidate))

# %%
evaluate_test(encoder1, attn_decoder1)
# Out:
# > उद वाचमीरयति हिन्वते मती पुरुष्टुतस्य कति चित्परिप्रियः|
# = he sendeth out his voice and many loving friends of him the highly lauded hasten with their songs.
# < age. appointed regarded ceremony ceremony for ceremony ceremony ceremony for ceremony apartment apartment apartment for ceremony apartment <EOS>
#
# > तव देव प्रसादाच्च भ्रातुश्च जयतां वर। कृतं न प्रतिकुर्याद्यः पुरुषाणां स दूषकः।।
# = 'O victorious lord he who does not repay the help got through your grace and your brother's is despicable among men.
# < Aware our our apartment our our apartment our apartment our apartment our <EOS>
#
# > ये नाकस्याधि रोचने दिवि देवास आसते|
# = who sit as deities in heaven above the skyvaults luminous sphere.
# < apartment made blasphemy: likewise). apartment apartment apartment apartment apartment apartment apartment <EOS>
#
# > यथैव धेनु स्स्रवति स्नेहाद्वत्सस्य वत्सला। तथा ममापि हृदयं मणिरत्नस्य दर्शनात्।।
# = "Just as a cow fond of its calf begins to distil milk from its teats at the sight of the calf, so does my heart melt at the sight of this excellent jewel.
# < show And ceremony apartment ceremony apartment ceremony apartment ceremony apartment ceremony apartment ceremony apartment ceremony apartment everybody ceremony apartment <EOS>
#
# > क्षिप्रं भवति धर्मात्मा शश्वच्छान्तिं निगच्छति। कौन्तेय प्रतिजानीहि न मे भक्तः प्रणश्यति।।
# =  Quickly he becomes righteous-souled (minded) and attains peace permanently. O son of Kunti ! I swear that my devotee gets never lost.
# < (by afterward, afterward, kingdom ceremony apartment our apartment our apartment apartment for apartment for our apartment <EOS>
#
# > अथो वयुछादुत्तराननु दयूनजराम्र्ता चरति सवधाभिः|
# = so will she shine on days to come immortal she moves on in her own strength undecaying.
# < his pass ceremony pass ceremony pass ceremony pass alone. <EOS>
#
# > स्वर्गेऽपि शोकं च विवर्णतां च। मया विना प्राप्प्यति वीर वाली। रम्ये नगेन्द्रस्य तटावकाशे। विदेहकन्यारहितो यथा त्वम्।।
# = 'O Rama Vali will experience sorrow and become pale bereft of me even in heaven just as you are filled with sorrow even on a delightful mountain slope bereft of princess of Videha.
# < teacher, ceremony us! everybody for ceremony for ceremony for ceremony apartment for ceremony everybody apartment <EOS>
#
# > तस्माद् गत्वा माकिदनियान्तर्व्वर्त्ति रोमीयवसतिस्थानं यत् फिलिपीनामप्रधाननगरं तत्रोपस्थाय कतिपयदिनानि तत्र स्थितवन्तः।
# =  O son of Prtha, not a single Yogin, knowing these two courses, gets deluded. Therefore, O Arjuna, be practising Yoga connected with all times.
# < Aware ceremony ceremony ceremony ceremony ceremony ceremony ceremony apartment ceremony apartment ceremony apartment apartment apartment apartment <EOS>
#
# > पौलस्त्यस्य वरिष्ठस्य रावणस्य महात्मनः। दशग्रीवस्य भार्या त्वं सीते न बहुमन्यसे।।
# = 'O Sita don't you think it is a privilege to be the  wife of the highsouled, tennecked Ravana, who is the distinguished king of a high family of sage Paulastya?
# < Through ceremony our ceremony apartment our apartment our our apartment ceremony our our apartment <EOS>
#
# > न मे जानाति सत्त्वं वा प्रभावं वाऽसितेक्षणा। तस्मात्पश्यतु वैदेही यद्रूपं मम कामतः।।
# = 'Blackeyed Sita is not aware of my strength or my power. Therefore let her see the real (huge) form that I can assume at my free will'.
# < (by take ceremony our our for ceremony ceremony our apartment ceremony for ceremony <EOS>
#
# > शुनमन्धाय भरमह्वयत सा वर्कीरश्विना वर्षणा नरेति|
# = to bring the blind man joy thus cried the shewolf o aśvins o ye mighty ones o heroes.
# < wish, ceremony made everybody for ceremony ceremony ceremony ceremony <EOS>
#
# > तदा यिहूदिया व्याहार्षुः, एतस्य मन्दिरस निर्म्माणेन षट्चत्वारिंशद् वत्सरा गताः, त्वं किं दिनत्रयमध्ये तद् उत्थापयिष्यसि?
# = Then said the Jews, Forty and six years was this temple in building, and wilt thou rear it up in three days?
# < age. pass Rama everybody for for apartment apartment apartment apartment apartment apartment apartment apartment <EOS>
#
# > चतुर्दिक्स्थनगरेभ्यो बहवो लोकाः सम्भूय रोगिणोऽपवित्रभुतग्रस्तांश्च यिरूशालमम् आनयन् ततः सर्व्वे स्वस्था अक्रियन्त।
# = There came also a multitude out of the cities round about unto Jerusalem, bringing sick folks, and them which were vexed with unclean spirits: and they were healed every one.
# < age. ceremony bring apartment apartment ceremony apartment ceremony apartment ceremony apartment apartment ceremony <EOS>
#
# > स राजा पुत्रशोकार्तः स्मृत्वा दुष्कृतमात्मनः। कौसल्यां पुत्रशोकार्तामिदं वचनमब्रवीत्।।
# = King Dasaratha distressed by the separation from his son, pondered over his past misdeed, and said to helpless Kausalya, who was equally grieving over the separation from Rama:
# < take apartment apartment apartment ceremony apartment apartment apartment ceremony apartment apartment <EOS>
#
# > अछा सवध्वरं जनम|
# = to people skilled in sacrifice.
# < apartment for ceremony <EOS>
#
# > उच्छाद्य स्नापयन्ति स्म नदीतीरेष वल्गुषु। अप्येकमेकं पुरषं प्रमदास्सप्त चाष्ट च।।
# = Every single warrior was attended by seven or eight women who applied oil and massaged his body and bathed him on the lovely banks of the river.
# < create ceremony beheld everybody ceremony for ceremony for ceremony apartment apartment apartment apartment apartment apartment apartment <EOS>
#
# > ततो नालीकनाराचैस्तीक्ष्णाग्रैश्च विकर्णिभिः। अभ्यवर्षन्महाघोरैर्गृध्रराजं महाबलः।।
# = Then the mighty Ravana rained sharp, dreadful shafts, spears and Vikarnis at Jatayu,  king of vultures.
# < for ceremony ceremony ceremony ceremony ceremony ceremony ceremony apartment ceremony ceremony <EOS>
#
# > न वर्धयेदघाहानि प्रत्यूहेन्नाग्निषु क्रियाः ।न च तत्कर्म कुर्वाणः सनाभ्योऽप्यशुचिर्भवेत्
# = Let him not (unnecessarily) lengthen the period of impurity, nor interrupt the rites to be performed with the sacred fires; for he who performs that (Agnihotra) rite will not be impure, though (he be) a (Sapinda) relative.
# < (by hath hath (by apartment for apartment for apartment apartment apartment for <EOS>
#
# > उद्वाव्र्षाणो राधसे तुविष्मान करन न इन्द्रः सुतीर्थाभयं च|
# = may mighty indra pouring forth in bounty bestow on us good roads and perfect safety.
# < wish, Just ceremony apartment apartment apartment apartment ceremony apartment <EOS>
#
# > भुरन्तु नो यशसः सोत्वन्धसो गरावाणो वाचा दिवितादिवित्मता|
# = stirred be the glorious stones let it press out the juice the stone with heavenly song that reaches up to heaven.
# < age. ceremony everybody ceremony for ceremony apartment ceremony apartment apartment for ceremony apartment apartment <EOS>
#
# > तमेवमुक्त्वा सुग्रीवो लक्ष्मणं शुभलक्षणम्। विसर्जयामास तदा तारामन्याश्च योषितः।।
# = Sugriva spoke to Lakshmana endowed with auspicious signs, and thereupon permitted Tara and other women to leave the place.
# < Aware ceremony everybody everybody apartment apartment apartment apartment apartment apartment <EOS>
#
# > दस्मो हि षमा वर्षणं पिन्वसि तवचं कं चिद यावीरररुं शूर मर्त्यं परिव्र्णक्षि मर्त्यम|
# = thou mighty pourest forth the hide that holds the rain thou keepest far away hero the wicked man thou shuttest out the wicked man.
# < (by hoped everybody ceremony bellowed apartment apartment apartment apartment apartment apartment apartment apartment apartment apartment apartment apartment apartment apartment <EOS>
#
# > पर ते सोतार ओण्यो रसं मदाय घर्ष्वय|
# = the pressers from the somapress send forth thy juice for rapturous joy.
# < might ascended known ceremony ceremony ceremony apartment ceremony <EOS>
#
# > इन्द्र पिब परतिकामं सुतस्य परातःसावस्तव हिपूर्वपीतिः|
# = drink of the juice o indra at thy plea sure for thy first draught is early morns libation.
# < wish, And ceremony bring apartment apartment apartment apartment apartment <EOS>
#
# > क उ नु ते महिमनः समस्यास्मत पूर्व रषयोअन्तमापुः|
# = who are the Ṛṣis then who comprehended before our time the bounds of all thy greatness.
# < age. pass Rama apartment for apartment ceremony for apartment ceremony apartment <EOS>
#
# > यतो यिहूदीयलोकानां मध्ये या या रीतिः सूक्ष्मविचाराश्च सन्ति तेषु भवान् विज्ञतमः; अतएव प्रार्थये धैर्य्यमवलम्ब्य मम निवेदनं शृणोतु।
# = Especially because I know thee to be expert in all customs and questions which are among the Jews: wherefore I beseech thee to hear me patiently.
# < Aware ceremony ceremony everybody ceremony ceremony ceremony ceremony apartment ceremony ceremony ceremony apartment ceremony <EOS>
#
# > स पिस्प्र्शति तन्वि शरुतस्य सत्र्भिर्न नाकं वचनस्यविपः|
# = may he the glorious lay upon his body the singers hymns as stars bedeck the heaven.
# < into made for apartment apartment for apartment apartment apartment apartment apartment apartment apartment <EOS>
#
#
# > स विहायोत्तरीयाणि महार्हाणि महायशाः। विसृज्य मनसा राज्यं जनन्यै मां समादिशत्।।
# = "Having given up the kingdom  voluntarily, Rama, a highly renowned king cast off his luxurious upper garments and asked me to take care of his mother.
# < Aware Hearing ceremony ceremony ceremony everybody ceremony ceremony ceremony everybody ceremony apartment ceremony everybody <EOS>
#
# > हरिः पर्यद्रवज्जाः सूर्यस्य दरोणं ननक्षे अत्यो न वाजी|
# = hither hath run the goldhued child of sūrya and reached the vat like a fleet vigorous courser.
# < hath father our our our apartment our apartment apartment our apartment our apartment <EOS>
#
# > विश्वे सतोमहान्त इत|
# = all of you verily are great.
# < made wrath apartment made ceremony ceremony <EOS>
#
# > हव्या च मानुषाणाम|
# = and to oblations brought by men.
# < apartment made ceremony apartment for everybody apartment ceremony apartment ceremony <EOS>
#
# > येषामर्थे काङ्क्षितं नो राज्यं भोगाः सुखानि च। त इमेऽवस्थिता युद्धे प्राणांस्त्यक्त्वा धनानि च।।
# =  [These are our] teachers, fathers, sons and also paternal grandfathers, maternal uncles, fathers-in-law, son's sons, wives' brothers, and (other) relatives.
# < king ceremony everybody for ceremony for ceremony everybody ceremony for everybody ceremony <EOS>
#
# > तदा यीशुः प्रत्यवादीत्, मदर्थं शब्दोयं नाभूत् युष्मदर्थमेवाभूत्।
# = Jesus answered and said, This voice came not because of me, but for your sakes.
# < apartment made apartment apartment apartment apartment apartment apartment apartment <EOS>
#
# > महीमहमिमां कृत्स्नामधितिष्ठन्तमात्मजम्। अनेन वयसा दृष्ट्वा यथास्वर्गमवाप्नुयाम्।।
# = 'Seeing my son ruling this entire dominion of the earth, I will experience the bliss of attaining heaven at this age.'
# < Just known purifying known ceremony known ceremony known ceremony known ceremony <EOS>
#
# > परि तवाग्ने पुरं वयं विप्रं सहस्य धीमहि|
# = we set thee round us as a fort victorious agni thee a sage.
# < teacher, ceremony bring for ceremony ceremony apartment apartment ceremony for ceremony apartment apartment apartment <EOS>
#
# > शातवनेये शतिनीभिरग्निः पुरुणीथे जरते सून्र्तावान|
# = is lauded excellent with hundred praises by purūṇītha son of Śatavani.
# < god made made made god made ceremony apartment ceremony apartment <EOS>
#
# > नास्य शत्रुर्न परतिमानमस्ति न परतिष्ठिःपुरुमायस्य सह्योः|
# = no foe hath he no counterpart no refuge is there from him the conqueror full of wisdom.
# < age. pass wish, आदिकाव्ये ceremony apartment our apartment ceremony <EOS>
#
# > सिन्धोरूर्मा वयक्षरन|
# = and fall into the rivers wave.
# < known sixty tidings tidings made <EOS>
#
# > यीशुस्तत् श्रुत्वा तान् प्रत्यवदत्, निरामयलोकानां चिकित्सकेन प्रयोजनं नास्ति, किन्तु सामयलोकानां प्रयोजनमास्ते।
# = But when Jesus heard that, he said unto them, They that be whole need not a physician, but they that are sick.
# < wish, made made made made made bring apartment apartment apartment <EOS>
#
# > किन्तु स गत्वा तत् कर्म्म इत्थं विस्तार्य्य प्रचारयितुं प्रारेभे तेनैव यीशुः पुनः सप्रकाशं नगरं प्रवेष्टुं नाशक्नोत् ततोहेतोर्बहिः काननस्थाने तस्यौ; तथापि चतुर्द्दिग्भ्यो लोकास्तस्य समीपमाययुः।
# = But he went out, and began to publish it much, and to blaze abroad the matter, insomuch that Jesus could no more openly enter into the city, but was without in desert places: and they came to him from every quarter.
# < (by ceremony regarded ceremony ceremony ceremony ceremony ceremony ceremony apartment ceremony ceremony apartment ceremony ceremony apartment ceremony for ceremony apartment <EOS>
#
# > आ नो रयिं सर्ववीरं सुनोतन देवाव्यम्भरत शलोकमद्रयः|
# = pour riches forth for us with troops of hero sons and bear ye up o stones the song that visits gods.
# < Through Aware On ceremony everybody for ceremony apartment apartment apartment apartment apartment for apartment apartment ceremony for <EOS>
#
# > पर हंसासस्त्र्पलं मन्युमछामादस्तं वर्षगणा अयासुः|
# = the swans the vrsaganas from anear us have brought their restless spirit to our dwelling.
# < ascended ascended ascended waiting his gold ceremony <EOS>
#
# > इमास्तास्तव राजेन्द्र वानर्योवल्लभास्सदा। पादैर्विकृष्ट मध्वानमागताः किं न बुध्यसे।।
# = 'O king of kings why don't you understand that these female monkeys, your wives who were dear to you have come on foot this long distance with great difficulty?
# < Through hath father our apartment ceremony apartment our apartment apartment <EOS>
#
# > तथा विलपतां तेषामतृप्तानां च राघवः। अचक्षुर्विषयं प्रायाद्यथार्कः क्षणदामुखे।।
# = Not yet satisfied (they wanted to linger longer), they stood weeping, while Rama went out of sight just as the Sun disappears at nightfall.
# < (by pleasant everybody ceremony ceremony ceremony apartment ceremony apartment for ceremony apartment ceremony apartment <EOS>
#
# > नकिरापिर्दद्र्शे मर्त्यत्रा किमङग रध्रचोदनन्त्वाहुः|
# = no friend among mankind have we to lookto why have men called thee him who spurs the niggard.
# < apartment made ceremony apartment ceremony apartment ceremony apartment <EOS>
#
# > यीशोः शयनस्थानस्य शिरःस्थाने पदतले च द्वयो र्दिशो द्वौ स्वर्गीयदूतावुपविष्टौ समपश्यत्।
# = And seeth two angels in white sitting, the one at the head, and the other at the feet, where the body of Jesus had lain.
# < wish, And ceremony for ceremony apartment apartment apartment apartment apartment for ceremony ceremony <EOS>
#
# > आ नो यातं दिवो अछा पर्थिव्या हिरण्ययेन सुव्र्ता रथेन|
# = come hitherward to us from earth from heaven borne on your golden chariot rolling lightly.
# < mighty. Rama hoped And Rama efforts everybody Rama apartment apartment apartment for everybody apartment ceremony <EOS>
#
# > सकलत्रस्य सन्देहो नित्यं यत्तस्य राघव। समर्थस्यापि हि सतो वासो दुःखमिहाद्य ते।।
# = O Rama, even though you are always vigilant and capable in all possible ways to defend youself, a doubt arises in our mind. It is perilous for you to live here with your wife.
# < (by beheld for ceremony for ceremony for for for for for ceremony apartment for for for apartment for for apartment for <EOS>
#
# > अति विश्वानि दुरिता पिपर्तन|
# = beyond all trouble and distress borne in your ship.
# < wish, tidings apartment ceremony bring ceremony apartment ceremony <EOS>
#
# > ततः परं यीशुः प्रतारकेण परीक्षितो भवितुम् आत्मना प्रान्तरम् आकृष्टः
# = even as the bull drives on the herds he drives the people with his might.
# < apartment sixty made ceremony apartment <EOS>
#
# > अस्मा इदु पर तवसे तुराय परयो न हर्मि सतोमं माहिनाय|
# = even to him swift strong and high exalted i bring my song of praise as dainty viands.
# < (by ceremony ceremony ceremony ceremony apartment ceremony apartment ceremony apartment apartment <EOS>
#
# > अस्माभिरू नु परतिचक्ष्याभूदो ते यन्ति ये अपरीषु पश्यान|
# = we we the living now behold her brightness and they come nigh who shall hereafter see her.
# < Through pass wish, for for for for for apartment for for <EOS>
#
# > स जिन्वते जठरेषु परजज्ञिवान वर्षा चित्रेषु नानदन न सिंहः|
# = he stirs with life in wombs dissimilar in kind born as a lion or a loudlybellowing bull.
# < age. might kingdom ceremony apartment apartment apartment apartment apartment apartment apartment apartment apartment apartment <EOS>
#
# > इति दुःखाभिसन्तप्तं विलपन्तमचेतनम्। घूर्णमानं महाराजं शोकेन समभिप्लुतम्। पारं शोकार्णवस्याशु प्रार्थयन्तं पुनः पुनः 	। प्रत्युवाचाथ कैकेयी रौद्रा रौद्रतरं वचः।।
# = Then the fierce Kaikeyi used fiercer words in reply to the king who was tormented with grief and filled with tears, senses switched off, head reeling, overwhelmed with pain, beseeching again and again to ferry him across the ocean of sorrow as quickly as possible:
# < (by ceremony ceremony ceremony ceremony ceremony ceremony for ceremony ceremony ceremony ceremony ceremony for ceremony ceremony ceremony ceremony for ceremony ceremony <EOS>
#
# > पीयति तवो अनु तवो गर्णाति वन्दारुस्ते तन्वं वन्देग्ने|
# = one hates thee and another sings thy praises i thine adorer laud thy form o agni.
# < king ceremony everybody ceremony ceremony ceremony ceremony ceremony everybody ceremony ceremony apartment <EOS>
#
# > भेजानसःसुवीर्यम|
# = and shared his great heroic might.
# < apartment ceremony ceremony apartment <EOS>
#
# > हर्म्यप्रासादसम्बाधां नानारत्नविभूषिताम्। द्रक्ष्यसि त्वं पुरीं लङ्कां विनष्टां मैथिलीकृते।।
# = You will see the city of Lanka dotted with magnificent royal mansions embellished  with different kinds of gems ruined for the sake of Sita.
# < (by ceremony regarded whose live kingdom ceremony everybody for everybody ceremony ceremony <EOS>
#
# > सलिलादूर्ध्वमुत्तिष्ठ तिष्ठत्वेष कपिस्त्वयि। अस्माकमतिथिश्चैव पूज्यश्च प्लवतां वरः।।
# = "Rise up from the waters. Let him rest on you since this noble monkey is our guest and worthy of worship.
# < for he ceremony he ceremony he ceremony ceremony he ceremony ceremony he ceremony <EOS>
#
# > मा नो अरातिरीशत देवस्य मर्त्यस्य च|
# = let no malignity prevail against us either gods or mans.
# < wish, ceremony ceremony for ceremony ceremony ceremony ceremony apartment <EOS>
#
# > वरुणाय रतपेशसे दधीत परयसे महे|
# = for varuṇa whose form is law place offerings for his great delight.
# < apartment sixty tidings the) splendour ceremony waiting apartment ceremony wrath apartment wrath apartment wrath <EOS>
#
# > सुपर्णवचनं श्रुत्वा सोंऽशुमानतिवीर्यवान् । त्वरितं हयमादाय पुनरायान्महायशा:।।
# = Exceedingly powerful and highly renowned Anshuman, on hearing the words of Garuda returned quickly to the capital with the horse৷৷
#
# > इत्थं तयोरतिशयविरोधस्योपस्थितत्वात् तौ परस्परं पृथगभवतां ततो बर्णब्बा मार्कं गृहीत्वा पोतेन कुप्रोपद्वीपं गतवान्;
# = And the contention was so sharp between them, that they departed asunder one from the other: and so Barnabas took Mark, and sailed unto Cyprus;
# < (by afterward, hath for ceremony apartment ceremony for ceremony apartment ceremony apartment ceremony for apartment ceremony <EOS>
#
# > अपरं तस्य क्लेशसमयस्याव्यवहितपरत्र सूर्य्यस्य तेजो लोप्स्यते, चन्द्रमा ज्योस्नां न करिष्यति, नभसो नक्षत्राणि पतिष्यन्ति, गगणीया ग्रहाश्च विचलिष्यन्ति।
# = Immediately after the tribulation of those days shall the sun be darkened, and the moon shall not give her light, and the stars shall fall from heaven, and the powers of the heavens shall be shaken:
# < king ceremony for ceremony for ceremony ceremony for ceremony ceremony for ceremony ceremony apartment for ceremony ceremony apartment <EOS>
#
# > श्रेणयस्त्वां महाराज पश्यन्त्वग्य्राश्च सर्वशः। प्रतपन्तमिवादित्यं राज्ये स्थित मरिन्दमम्।।
# = O great king and subduer of enemies, may all the leading guilds of traders and other subjects behold you all over installed in the kingdom like the resplendent Sun.
# < age. pass wish, आदिकाव्ये ceremony ceremony for ceremony ceremony <EOS>
#
# > अभि गोत्राणि सहसा गाहमानोअदयो वीरः शतमन्युरिन्द्रः|
# = piercing the cowstalls with surpassing vigour indra the pitiless hero wild with anger.
# < apartment apartment apartment apartment apartment apartment apartment apartment apartment apartment <EOS>
#
# > नेत तवा धर्ष्णुर्हरसा जर्ह्र्षाणो दध्र्ग्विधक्ष्यन पर्यङखयाते|
# = so will the bold one eager to attack thee with fierce glow fail to girdle and consume thee.
# < (by pleasant everybody ceremony ceremony ceremony apartment ceremony for ceremony ceremony apartment apartment ceremony <EOS>
#
# > वज्रवैडूर्यगर्भाणि श्रवणान्तेषु योषिताम्। ददर्श तापनीयानि कुण्डलान्यङ्गदानि च।।
# = He noticed on the earlobes of the the women gold earrings decked with diamonds and vaidurya. They were wearing shining armlets of gold.
# < create ceremony everybody ceremony ceremony apartment ceremony apartment apartment apartment apartment <EOS>
#
# > आ नो गोमन्तमश्विना सुवीरं सुरथं रयिम|
# = o aśvins bring us wealth in kine in noble heroes and in cars.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-37-97ac4295f4c7> in <module>()
# ----> 1 evaluate_test(encoder1, attn_decoder1)
#
# <ipython-input-24-7879407f1279> in evaluate_test(encoder, decoder)
#       5       print('>', pair[0])
#       6       print('=', pair[1])
# ----> 7       output_words, attentions = evaluate(encoder, decoder, pair[0])
#       8       output_sentence = ' '.join(output_words)
#       9       print('<', output_sentence)
#
# <ipython-input-23-881d27a56888> in evaluate(encoder, decoder, sentence, max_length)
#      12             encoder_outputs[ei] += encoder_output[0, 0]
#      13
# ---> 14         decoder_input = torch.tensor([[SOS_token]], device=device)  # SOS
#      15
#      16         decoder_hidden = encoder_hidden
#
# RuntimeError: CUDA error: device-side assert triggered
